# %%
import pandas as pd
import os
import numpy as np
from itertools import combinations
from matplotlib import pyplot as plt
import pdfcrowd

# %%
# %pip install pdfcrowd
# Out:
# Requirement already satisfied: pdfcrowd in c:\users\chowdary\appdata\local\programs\python\python38\lib\site-packages (5.1.3)Note: you may need to restart the kernel to use updated packages.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security       gain
# 457   539730  34.088000
# 306   532790  13.876684
# 342   532960  12.369261
# 159   524634   9.699531
# 397   533520   8.786756
# 204   530313   8.400000
# 541   590021   8.184953
# 386   533398   5.802244
# 273   532734   5.659405
# 51    511539   5.025157

# %%
pip
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   c:\users\chowdary\appdata\local\programs\python\python38\python.exe -m pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
#   help                        Show help for commands.
#
# General Options:
#   -h, --help                  Show help.
#   --isolated                  Run pip in an isolated mode, ignoring
#                               environment variables and user configuration.
#   -v, --verbose               Give more output. Option is additive, and can be
#                               used up to 3 times.
#   -V, --version               Show version and exit.
#   -q, --quiet                 Give less output. Option is additive, and can be
#                               used up to 3 times (corresponding to WARNING,
#                               ERROR, and CRITICAL logging levels).
#   --log <path>                Path to a verbose appending log.
#
#   --no-input                  Disable prompting for input.
#   --proxy <proxy>             Specify a proxy in the form
#                               [user:passwd@]proxy.server:port.
#   --retries <retries>         Maximum number of retries each connection should
#                               attempt (default 5 times).
#   --timeout <sec>             Set the socket timeout (default 15 seconds).
#   --exists-action <action>    Default action when a path already exists:
#                               (s)witch, (i)gnore, (w)ipe, (b)ackup, (a)bort.
#   --trusted-host <hostname>   Mark this host or host:port pair as trusted,
#                               even though it does not have valid or any HTTPS.
#   --cert <path>               Path to PEM-encoded CA certificate bundle. If
#                               provided, overrides the default. See 'SSL
#                               Certificate Verification' in pip documentation
#                               for more information.
#   --client-cert <path>        Path to SSL client certificate, a single file
#                               containing the private key and the certificate
#                               in PEM format.
#   --cache-dir <dir>           Store the cache data in <dir>.
#   --no-cache-dir              Disable the cache.
#   --disable-pip-version-check
#                               Don't periodically check PyPI to determine
#                               whether a new version of pip is available for
#                               download. Implied with --no-index.
#   --no-color                  Suppress colored output.
#   --no-python-version-warning
#                               Silence deprecation warnings for upcoming
#                               unsupported Pythons.
#   --use-feature <feature>     Enable new functionality, that may be backward
#                               incompatible.
#   --use-deprecated <feature>  Enable deprecated functionality, that will be
#                               removed in the future.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:750]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security       gain
# 306   532790  20.685801
# 457   539730  16.544000
# 204   530313   8.400000
# 355   532989   5.137631
# 51    511539   5.025157
# 503   542726   3.794902
# 53    511549   3.658902
# 491   540823   3.424484
# 254   532541   3.321775
# 505   542752   3.309165

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:500]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security       gain
# 306   532790  22.457516
# 355   532989   6.463983
# 51    511539   5.025157
# 503   542726   3.794902
# 491   540823   3.424484
# 505   542752   3.309165
# 185   530219   3.282407
# 228   532482   3.147831
# 163   524663   3.147255
# 213   531672   2.837012

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:250]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security      gain
# 306   532790  9.298422
# 355   532989  8.033333
# 163   524663  5.541995
# 51    511539  5.025157
# 146   524572  4.416129
# 84    514175  3.939286
# 20    504180  3.626728
# 491   540823  3.424484
# 185   530219  3.282407
# 213   531672  2.837012

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:130]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security       gain
# 355   532989  21.583333
# 306   532790   9.196023
# 185   530219   4.040872
# 537   570005   3.500000
# 266   532617   3.013817
# 213   531672   2.843537
# 160   524640   2.794643
# 506   542753   2.735369
# 482   540782   2.713178
# 163   524663   2.665441

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:75]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security       gain
# 355   532989  17.940860
# 266   532617   3.225455
# 423   535917   3.180952
# 146   524572   2.932084
# 476   540253   2.829787
# 108   521210   2.492647
# 111   521222   2.053571
# 450   539274   2.000000
# 199   530291   1.883436
# 264   532614   1.722222

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file,thousands=",")
            df = df[0:30]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by="Date",inplace=True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(),columns=["security","gain"])
df.sort_values(by="gain",inplace=True,ascending=False)
df.head(10)
# Out:
#     security      gain
# 355   532989  2.317326
# 321   532813  1.560440
# 308   532795  1.527273
# 39    511431  1.512241
# 5     500013  1.491991
# 423   535917  1.251282
# 266   532617  1.204934
# 479   540266  1.102362
# 500   542694  1.058333
# 181   530201  1.056000

# %%
dfs = {}
stock_names = set()
def read_dfs():
    for root,dirs,files in os.walk(os.curdir):
        for file in files:
            if len(stock_names) == 30:
                return
            if file.endswith('.csv') and file.startswith("5"):
                name = os.path.splitext(file)[0]
                df = pd.read_csv(file,thousands=",")
                dfs[name] = df
                stock_names.add(name)
read_dfs()

# %%
samp = pd.DataFrame(columns=stock_names,index=stock_names)
for n1,n2 in combinations(stock_names,2):
    df1 = dfs[n1]
    df2 = dfs[n2]
    c1 = df1["Total Turnover (Rs.)"].corr(df2["Total Turnover (Rs.)"])
    c2 = df2["Total Turnover (Rs.)"].corr(df1["Total Turnover (Rs.)"])
    samp.loc[n1,n2] = c1
    samp.loc[n2,n1] = c2
    samp.loc[n1,n1] = 1
    samp.loc[n2,n2] = 1
samp = samp.astype({name:"float" for name in stock_names})

# %%
samp.style.background_gradient(cmap="brg")
# Out:
# <style  type="text/css" >
# #T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col0,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow1_col1,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow2_col2,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow3_col3,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow4_col4,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow5_col5,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow6_col6,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow7_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow8_col8,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow9_col9,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow10_col10,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow11_col11,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow12_col12,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow13_col13,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow14_col14,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow15_col15,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow16_col16,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow17_col17,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow18_col18,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow19_col19,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow20_col20,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow21_col21,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow22_col22,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow23_col23,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow24_col24,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow25_col25,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow26_col26,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow27_col27,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow28_col28,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow29_col29{
#             background-color:  #00ff00;
#             color:  #000000;
#         }#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col1,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col5,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col9,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col14,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow1_col5,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow2_col25,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow3_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow5_col25,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow8_col2,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow9_col5,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow10_col25,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow14_col5,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow14_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow17_col5,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow19_col1,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow19_col3,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow19_col5,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow19_col6,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow19_col12,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow20_col5,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow22_col5,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow25_col12,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow25_col13,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow27_col4,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow28_col9,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow28_col27{
#             background-color:  #1400eb;
#             color:  #f1f1f1;
#         }#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col2,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col3,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col16,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow1_col28,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow2_col15,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow3_col20,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow4_col2,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow4_col8,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow7_col28,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow10_col13,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow10_col24,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow11_col1,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow11_col9,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow12_col0,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow13_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow13_col9,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow13_col27,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow16_col21,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow17_col22,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow17_col29,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow18_col17,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow20_col24,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow24_col20,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow25_col19,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow28_col2{
#             background-color:  #2600d9;
#             color:  #f1f1f1;
#         }#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col4,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow1_col25,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow2_col24,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow3_col16,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow4_col14,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow5_col22,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow5_col27,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow6_col4,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow11_col6,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow12_col6,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow13_col2,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow14_col15,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow15_col11,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow21_col6,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow21_col17,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow23_col28,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow26_col16,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow28_col4,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow29_col18,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow29_col22,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow29_col28{
#             background-color:  #3a00c5;
#             color:  #f1f1f1;
#         }#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col6,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col27,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow2_col27,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow2_col29,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow4_col13,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow4_col16,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow4_col25,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow5_col12,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow6_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow10_col6,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow10_col16,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow11_col29,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow12_col20,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow12_col29,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow13_col3,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow13_col8,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow14_col2,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow15_col17,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow15_col19,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow16_col13,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow17_col20,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow18_col27,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow19_col29,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow21_col9,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow22_col12,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow27_col20,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow28_col20,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow29_col16{
#             background-color:  #2200dd;
#             color:  #f1f1f1;
#         }#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow2_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow4_col9,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow5_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow8_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow10_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow11_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow12_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow12_col10,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow13_col10,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow14_col13,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow16_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow17_col10,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow20_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow22_col7,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow22_col21,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow27_col1,#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow29_col2{
#             background-color:  #0a00f5;
#             color:  #f1f1f1;
#         }#T_e63a9c56_d44d_11eb_9c5a_ec8eb5417d3frow0_col8,#T_e63a9c56_d44d_11

# %%
import base64
import io


def spark_line(data, figsize=(4, 0.25), **kwags):
    data = list(data)

    fig, ax = plt.subplots(1, 1, figsize=figsize, **kwags)
    ax.plot(data)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])

    plt.plot(len(data) - 1, data[len(data) - 1], 'r.')

    ax.fill_between(range(len(data)), data, len(data)*[min(data)], alpha=0.1)

    img = io.BytesIO()
    plt.savefig(img, transparent=True, bbox_inches='tight')
    img.seek(0)
    plt.close()

    return base64.b64encode(img.read()).decode("UTF-8")

# %%
values = [23,80,92,62,98,7,9,56,19,68]


with open("sparkline2.html", "a") as file:
        file.write('<div><h1>Sparkline to the given values</h1></div>')
        file.write('<br>')
        file.write('<br>')
        file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(values)))
        file.write('<div></div>')

# %%
closing_price_values = list()
for file in os.listdir():
    if file.endswith('.csv') and file.startswith("5"):
        filename = os.path.splitext(file)[0]
        if not filename.isdecimal() :
            continue
        df = pd.read_csv(file,thousands=",")
        try:
            closing_price_values.append(df["Close"][0:30].values)
        except Exception as e:
            closing_price_values.append(df["Close Price"][0:30].values)

with open("bse_closing_price3.html", "a") as file:
    file.write('<div><h1>Sparkline to the Closing Price values</h1></div>')
    file.write('<br>')
    file.write('<br>')
    for value in closing_price_values:
        file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

# %%
client = pdfcrowd.HtmlToPdfClient('demo', 'ce544b6ea52a5621fb9d55f8b542d14d')
client.convertFileToFile('bse_closing_price3.html', 'bse_closing_price3.pdf')
